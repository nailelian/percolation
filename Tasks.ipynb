# %%
from percolation import *

P_10 = Percolation(np.zeros((10,10)))
PT_10 = PercolationTools(P_10)

# %% [markdown]
# ## Task 1

# %%
import matplotlib.pyplot as plt

trials = 3

fig, axs = plt.subplots(nrows = trials, ncols=3, figsize=(15, 15))

for i in range(0, trials):
    P_10.percolate(0.25)
    PT_10.display(axs[i,0])
    axs[i,0].set_title('p = 0.25')
    P_10.percolate(0.5)
    PT_10.display(axs[i,1])
    axs[i,1].set_title('p = 0.5')
    P_10.percolate(0.75)
    PT_10.display(axs[i,2])
    axs[i,2].set_title('p = 0.75')

# %% [markdown]
# $F_n(p)$ appears to be low for $p<0.5$ and large for $p>0.5$

# %% [markdown]
# ## Task 2

# %%
iters = 50

P_05 = Percolation(np.zeros((5, 5)))

print("F_5(0.25) ≈ ", P_05.simulate(iters, 0.25))
print("F_10(0.25) ≈ ", P_10.simulate(iters, 0.25))

print("F_5(0.5) ≈ ", P_05.simulate(iters, 0.5))
print("F_10(0.5) ≈ ", P_10.simulate(iters, 0.5))

print("F_5(0.75) ≈ ", P_05.simulate(iters, 0.75))
print("F_10(0.75) ≈ ", P_10.simulate(iters, 0.75))
# Out:
# F_5(0.25) ≈  0.04
# F_10(0.25) ≈  0.0
# F_5(0.5) ≈  0.4
# F_10(0.5) ≈  0.22
# F_5(0.75) ≈  0.8
# F_10(0.75) ≈  0.94

# %% [markdown]
# ## Task 3
#
# pretty happy with efficiency of path function
#
# ## Task 4
#
# First we'll try computing a whole load of values and plotting them. Then we'll use a binary search to hone in on $p_c$

# %%
P_50 = Percolation(np.zeros((50, 50)))
PT_50 = PercolationTools(P_50)

PT_50.find_critical_value_g(20, 1)

# %%
print("pc = ", PT_50.find_critical_value_bs(50, 20))
# Out:
# 0 0.5 1 0.0
# 0.5 0.75 1 1.0
# 0.5 0.625 0.75 0.86
# 0.5 0.5625 0.625 0.08
# 0.5625 0.59375 0.625 0.48
# 0.59375 0.609375 0.625 0.78
# 0.59375 0.6015625 0.609375 0.56
# 0.59375 0.59765625 0.6015625 0.58
# 0.59375 0.595703125 0.59765625 0.54
# 0.59375 0.5947265625 0.595703125 0.5
# 0.59375 0.59423828125 0.5947265625 0.54
# 0.59375 0.593994140625 0.59423828125 0.48
# 0.593994140625 0.5941162109375 0.59423828125 0.42
# 0.5941162109375 0.59417724609375 0.59423828125 0.54
# 0.5941162109375 0.594146728515625 0.59417724609375 0.48
# 0.594146728515625 0.5941619873046875 0.59417724609375 0.58
# 0.594146728515625 0.5941543579101562 0.5941619873046875 0.42
# 0.5941543579101562 0.5941581726074219 0.5941619873046875 0.54
# 0.5941543579101562 0.5941562652587891 0.5941581726074219 0.56
# 0.5941543579101562 0.5941553115844727 0.5941562652587891 0.5
# pc =  0.5941548347473145

# %% [markdown]
# ## Task 7

# %%
TP_20 = TriPercolation(np.zeros((10,10)))
TPT_20 = PercolationTools(TP_20)

print("pc = ", TPT_20.find_critical_value_bs(50, 20))
# Out:
# 0 0.5 1 0.42
# 0.5 0.75 1 1.0
# 0.5 0.625 0.75 0.82
# 0.5 0.5625 0.625 0.76
# 0.5 0.53125 0.5625 0.58
# 0.5 0.515625 0.53125 0.5
# 0.5 0.5078125 0.515625 0.5
# 0.5 0.50390625 0.5078125 0.42
# 0.50390625 0.505859375 0.5078125 0.56
# 0.50390625 0.5048828125 0.505859375 0.48
# 0.5048828125 0.50537109375 0.505859375 0.56
# 0.5048828125 0.505126953125 0.50537109375 0.38
# 0.505126953125 0.5052490234375 0.50537109375 0.5
# 0.505126953125 0.50518798828125 0.5052490234375 0.5
# 0.505126953125 0.505157470703125 0.50518798828125 0.54
# 0.505126953125 0.5051422119140625 0.505157470703125 0.58
# 0.505126953125 0.5051345825195312 0.5051422119140625 0.6
# 0.505126953125 0.5051307678222656 0.5051345825195312 0.46
# 0.5051307678222656 0.5051326751708984 0.5051345825195312 0.46
# 0.5051326751708984 0.5051336288452148 0.5051345825195312 0.4
# pc =  0.505134105682373

# %% [markdown]
# ## Task 8

# %%
epsilons = [0.1, 0.01, 0.001, 0.0001, 0.2, 0.02, 0.002, 0.0002]
Gs = []
